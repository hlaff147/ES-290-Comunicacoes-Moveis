# %% [markdown]
# # Libs and Initial Dataframes

# %%
import numpy as np
import pandas as pd

# %%
bt_df = pd.read_csv('../processed_files/bts.csv', delimiter=',', encoding='utf-8')
df_train = pd.read_csv('../processed_files/meds_train_alunos.csv', delimiter=',', encoding='utf-8')

# %% [markdown]
# # Visualizing dataframes basic infos

# %% [markdown]
# ## BTSs

# %%
bt_df = bt_df.iloc[:, 1:].drop(columns=['id_bts', 'nom_bts', 'nom_canal_controle_bts'])

# %%
bt_df
# Out:
#    id_localizacao_setor  num_lat_bts num_long_bts  num_azimuth   id_rrsi
# 0                     1     -804.342      -34.952            0  rssi_1_1
# 1                     1     -804.342      -34.952          120  rssi_1_2
# 2                     1     -804.342      -34.952          240  rssi_1_3
# 3                     2     -805.289  -34.944.672            0  rssi_2_1
# 4                     2     -805.289  -34.944.672          120  rssi_2_2
# 5                     2     -805.289  -34.944.672          240  rssi_2_3
# 6                     3     -805.532     -349.579            0  rssi_3_1
# 7                     3     -805.532     -349.579          120  rssi_3_2
# 8                     3     -805.532     -349.579          240  rssi_3_3

# %% [markdown]
# # Train DF

# %%
df_train = df_train.iloc[:, 1:]
df_train
# Out:
#       id_ponto  rssi_1_1  rssi_1_2  rssi_1_3  rssi_2_1  rssi_2_2  rssi_2_3  \
# 0         6604  -103.705  -110.425       NaN   -110.33  -108.345   -106.59
# 1         5515  -105.225  -115.000   -105.21   -115.00  -105.835   -115.00
# 2         5049  -102.610  -115.000   -101.38   -115.00  -104.295    -97.36
# 3         8737   -89.140       NaN       NaN       NaN  -965.925    -92.46
# 4         1203       NaN  -107.200   -107.01   -108.43       NaN       NaN
# ...        ...       ...       ...       ...       ...       ...       ...
# 6770      5734  -105.225  -115.000   -105.21   -115.00  -105.835   -115.00
# 6771      5191  -105.225  -115.000   -105.21   -115.00  -105.835   -115.00
# 6772      5390  -105.225  -115.000   -105.21   -115.00  -105.835   -115.00
# 6773       860       NaN  -107.200   -107.01   -108.43   -97.200       NaN
# 6774      7270       NaN       NaN       NaN    -85.12   -83.190       NaN
#
# ...
